# %%
import numpy as np
import pandas as pd


# volume formula given sides
def volume(s_01, s_02, s_12, s_03, s_13, s_23):
    squared_vol = (
        (2 * s_01 * s_02 * s_03) ** 2
        + (s_01**2 + s_02**2 - s_12**2)
        * (s_01**2 + s_03**2 - s_13**2)
        * (s_02**2 + s_03**2 - s_23**2)
        - (s_01**2) * (s_02**2 + s_03**2 - s_23**2) ** 2
        - (s_02**2) * (s_01**2 + s_03**2 - s_13**2) ** 2
        - (s_03**2) * (s_01**2 + s_02**2 - s_12**2) ** 2
    )
    return squared_vol


# We will start from the longest side and then work our way downwards

s_01 = 1  # longest side
while s_01 < 100:
    if s_01 % 10 == 0:
        print(s_01)
    for s_02 in range(1, s_01 + 1):
        for s_12 in range(1, s_02 + 1):
            if s_12 + s_02 > s_01:  # triangle inequality for the base triangle
                base_area_squared = (
                    (s_01 + s_02 + s_12)
                    * (-s_01 + s_02 + s_12)
                    * (s_01 - s_02 + s_12)
                    * (s_01 + s_02 - s_12)
                    / 16
                )
                min_height = max(0, int(np.sqrt(8 / base_area_squared)) - 1)
                for s_03 in range(min_height, s_02 + 1):  # vertex 3 is the apex
                    for s_13 in range(min_height, s_02 + 1):
                        if s_01 + s_03 > s_13:
                            for s_23 in range(min_height, s_02 + 1):
                                if (s_02 + s_03 > s_23) and (s_12 + s_13 > s_23):
                                    vol = volume(s_01, s_02, s_12, s_03, s_13, s_23)
                                    if vol == 128:
                                        print(s_01, s_02, s_12, s_03, s_13, s_23, vol)
                                    elif vol > 128:
                                        break
                                else:
                                    break
                        else:
                            break
            else:
                break

    s_01 += 1
# Out:
# 2 2 2 2 2 2 128
# 10
# 20
# 30
# 40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 40
#      38 for s_23 in range(min_height, s_02 + 1):
#      39     if (s_02 + s_03 > s_23) and (s_12 + s_13 > s_23):
# ---> 40         vol = volume(s_01, s_02, s_12, s_03, s_13, s_23)
#      41         if vol == 128:
#      42             print(s_01, s_02, s_12, s_03, s_13, s_23, vol)
#
# KeyboardInterrupt:

# %%
import numpy as np
from multiprocessing import Pool


# Volume formula given sides
def volume(s_01, s_02, s_12, s_03, s_13, s_23):
    squared_vol = (
        (2 * s_01 * s_02 * s_03) ** 2
        + (s_01**2 + s_02**2 - s_12**2)
        * (s_01**2 + s_03**2 - s_13**2)
        * (s_02**2 + s_03**2 - s_23**2)
        - (s_01**2) * (s_02**2 + s_03**2 - s_23**2) ** 2
        - (s_02**2) * (s_01**2 + s_03**2 - s_13**2) ** 2
        - (s_03**2) * (s_01**2 + s_02**2 - s_12**2) ** 2
    )
    return squared_vol


# Function to process a single s_01 value
def process_s_01(s_01):
    results = []
    for s_02 in range(1, s_01 + 1):
        for s_12 in range(1, s_02 + 1):
            if s_12 + s_02 > s_01:  # Triangle inequality for the base triangle
                base_area_squared = (
                    (s_01 + s_02 + s_12)
                    * (-s_01 + s_02 + s_12)
                    * (s_01 - s_02 + s_12)
                    * (s_01 + s_02 - s_12)
                    / 16
                )
                min_height = max(0, int(np.sqrt(8 / base_area_squared)) - 1)
                for s_03 in range(min_height, s_02 + 1):  # Vertex 3 is the apex
                    for s_13 in range(min_height, s_02 + 1):
                        if s_01 + s_03 > s_13:
                            for s_23 in range(min_height, s_02 + 1):
                                if (s_02 + s_03 > s_23) and (s_12 + s_13 > s_23):
                                    vol = volume(s_01, s_02, s_12, s_03, s_13, s_23)
                                    if vol == 128:
                                        results.append(
                                            (s_01, s_02, s_12, s_03, s_13, s_23, vol)
                                        )
                                    elif vol > 128:
                                        break
                                else:
                                    break
                        else:
                            break
            else:
                break
    return results


# Main execution
if __name__ == "__main__":
    from tqdm import tqdm

    # Define range of s_01 values
    s_01_values = range(1, 100)

    # Create a pool of workers
    with Pool() as pool:
        # Use tqdm for progress bar
        results = list(
            tqdm(pool.imap(process_s_01, s_01_values), total=len(s_01_values))
        )

    # Flatten the results list
    all_results = [item for sublist in results for item in sublist]

    # Print the results
    for result in all_results:
        print(result)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]Process SpawnPoolWorker-88:
# Process SpawnPoolWorker-87:
# Process SpawnPoolWorker-83:
# Process SpawnPoolWorker-82:
# Process SpawnPoolWorker-86:
# Process SpawnPoolWorker-85:
# Process SpawnPoolWorker-84:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-89:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-90:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-91:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-92:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-93:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-94:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-95:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-96:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-97:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-98:
# Process SpawnPoolWorker-99:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-100:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-102:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-101:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-103:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-104:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-105:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-106:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-107:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-109:
# Process SpawnPoolWorker-108:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-110:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-111:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-112:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-113:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-114:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-116:
# Process SpawnPoolWorker-115:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-118:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-117:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-119:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-121:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-120:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-122:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-123:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-124:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-125:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-126:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-128:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-127:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-130:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-129:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-132:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-131:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-133:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-134:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-136:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-135:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-137:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-138:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-139:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-140:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-142:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-141:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-143:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-144:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-145:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-146:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-147:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-148:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-149:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-150:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-151:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-152:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-153:
# ...
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-161:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-162:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-163:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-164:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-165:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-166:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-167:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-169:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-168:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-170:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-171:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-172:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-173:
# Process SpawnPoolWorker-174:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-175:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-177:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-176:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-178:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-179:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-180:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_s_01' on <module '__main__' (built-in)>
#   0%|          | 0/99 [01:03<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 57
#      54 # Create a pool of workers
#      55 with Pool() as pool:
#      56     # Use tqdm for progress bar
# ---> 57     results = list(tqdm(pool.imap(process_s_01, s_01_values), total=len(s_01_values)))
#      59 # Flatten the results list
#      60 all_results = [item for sublist in results for item in sublist]
#
# File /opt/miniconda3/envs/BayesianDL/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /opt/miniconda3/envs/BayesianDL/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /opt/miniconda3/envs/BayesianDL/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
